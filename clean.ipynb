# %%
import pandas as pd
df1 = pd.read_csv('2020_lar.txt',sep='|', low_memory=False, nrows=6000000)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000000 entries, 0 to 5999999
# Data columns (total 99 columns):
#  #   Column                                    Dtype
# ---  ------                                    -----
#  0   activity_year                             int64
#  1   lei                                       object
#  2   derived_msa_md                            int64
#  3   state_code                                object
#  4   county_code                               float64
#  5   census_tract                              float64
#  6   conforming_loan_limit                     object
#  7   derived_loan_product_type                 object
#  8   derived_dwelling_category                 object
#  9   derived_ethnicity                         object
#  10  derived_race                              object
#  11  derived_sex                               object
#  12  action_taken                              int64
# ...

# %%
df1.head(5)
# Out:
#    activity_year                   lei  derived_msa_md state_code  \
# 0           2020  549300EOHSB7M6IFW844           19660         FL
# 1           2020  549300EOHSB7M6IFW844           23540         FL
# 2           2020  549300EOHSB7M6IFW844           29460         FL
# 3           2020  549300EOHSB7M6IFW844           45300         FL
# 4           2020  549300EOHSB7M6IFW844           99999         FL
#
#    county_code  census_tract conforming_loan_limit derived_loan_product_type  \
# 0      12127.0  1.212709e+10                     C   Conventional:First Lien
# 1      12001.0  1.200100e+10                     C        FSA/RHS:First Lien
# 2      12105.0  1.210501e+10                     C   Conventional:First Lien
# 3      12053.0  1.205304e+10                     C   Conventional:First Lien
# 4      12125.0  1.212596e+10                     C   Conventional:First Lien
#
#               derived_dwelling_category        derived_ethnicity  ...  \
# ...

# %%
print(df1.lei.unique())
# Out:
# ['549300EOHSB7M6IFW844' '549300OMHGOGEWTCI138' '254900I3LJYL57NZ5H21' ...
#  '5493001XKL0FTNOJ0866' '549300PNAL4XWOQBBP76' 'JJKC32MCHWDI71265Z06']

# %%
df1.head(150).to_csv("test.csv")

# %% [markdown]
# # Remove Some Columns

# %%
remove = ['total_points_and_fees', 'lender_credits', "prepayment_penalty_term", "intro_rate_period", 
               "multifamily_affordable_units", 
               'applicant_ethnicity_2','applicant_ethnicity_3', 'applicant_ethnicity_4', 'applicant_ethnicity_5', 
               'co_applicant_ethnicity_2', 'co_applicant_ethnicity_3', 'co_applicant_ethnicity_4', 
               'co_applicant_ethnicity_5', 'applicant_race_2','applicant_race_3', 'applicant_race_4', 
               'applicant_race_5', 
               'co_applicant_race_2', 'co_applicant_race_3', 'co_applicant_race_4', 
               'co_applicant_race_5', 'aus_2', 'aus_3', 'aus_4', 'aus_5','denial_reason_2','denial_reason_3'
              ,'denial_reason_4']

new_headers = []
for column in df1.columns:
    if column not in remove:
        new_headers.append(column)
        
print(len(new_headers))
# Out:
# 71

# %%
df2 = df1[new_headers].copy()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000000 entries, 0 to 5999999
# Data columns (total 71 columns):
#  #   Column                                    Dtype
# ---  ------                                    -----
#  0   activity_year                             int64
#  1   lei                                       object
#  2   derived_msa_md                            int64
#  3   state_code                                object
#  4   county_code                               float64
#  5   census_tract                              float64
#  6   conforming_loan_limit                     object
#  7   derived_loan_product_type                 object
#  8   derived_dwelling_category                 object
#  9   derived_ethnicity                         object
#  10  derived_race                              object
#  11  derived_sex                               object
#  12  action_taken                              int64
# ...

# %%
df2.to_csv('cleaned.csv', index = False)
